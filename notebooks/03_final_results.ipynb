# %% [markdown]
# # Final Results Analysis
#
# This notebook analyzes and visualizes final results from all experiments.

# %%
import sys
from pathlib import Path
sys.path.append('../')

from experiments.analyze_results import load_all_metrics, create_comparison_table
from src.evaluation import compare_models

# Load all metrics
metrics_dict = load_all_metrics()

# Print comparison
compare_models(metrics_dict)

# Create visualization
df = create_comparison_table(metrics_dict)

# Display dataframe
print("\nDetailed Results Table:")
print(df.to_string())
