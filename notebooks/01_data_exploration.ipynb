# %% [markdown]
# # IMDB Dataset Exploration
#
# This notebook explores the IMDB Movie Reviews dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import sys

sys.path.append('../')
from src.preprocessing import prepare_imdb_dataset

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Load dataset
data_dir = '../data/raw/aclImdb'
train_df, test_df = prepare_imdb_dataset(data_dir, '../data/processed')
